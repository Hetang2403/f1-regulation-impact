# %%
import pandas as pd
df = pd.read_parquet('../code/src/data/processed/team_race_panel_forecast.parquet')
print(df['race'].unique())
# Out:
# ['Australian Grand Prix' 'Bahrain Grand Prix' 'Chinese Grand Prix'
#  'Azerbaijan Grand Prix' 'Spanish Grand Prix' 'Monaco Grand Prix'
#  'Canadian Grand Prix' 'French Grand Prix' 'Austrian Grand Prix'
#  'British Grand Prix' 'German Grand Prix' 'Hungarian Grand Prix'
#  'Belgian Grand Prix' 'Italian Grand Prix' 'Singapore Grand Prix'
#  'Russian Grand Prix' 'Japanese Grand Prix' 'Mexican Grand Prix'
#  'United States Grand Prix' 'Brazilian Grand Prix' 'Abu Dhabi Grand Prix'
#  'Styrian Grand Prix' '70th Anniversary Grand Prix' 'Tuscan Grand Prix'
#  'Eifel Grand Prix' 'Portuguese Grand Prix' 'Emilia Romagna Grand Prix'
#  'Turkish Grand Prix' 'Sakhir Grand Prix' 'Dutch Grand Prix'
#  'Mexico City Grand Prix' 'São Paulo Grand Prix' 'Qatar Grand Prix'
#  'Saudi Arabian Grand Prix' 'Miami Grand Prix' 'Las Vegas Grand Prix']

# %%
df[df['race'] == 'Canadian Grand Prix']['year'].unique()
# Out:
# array([2019, 2022, 2023, 2024, 2025])

# %%
import pandas as pd
df = pd.read_parquet("../code/src/data/processed/team_race_panel.parquet")
print(df.dtypes)
print(df.head(2))
# Out:
# year               int64
# round              int64
# team              object
# avg_points       float64
# avg_position     float64
# race              object
# relative_perf    float64
# post               int64
# treated            int64
# dtype: object
#    year  round        team  avg_points  avg_position                   race  \
# 0  2019      1  AlphaTauri         0.5          12.0  Australian Grand Prix
# 1  2019      1      Alpine         3.0          13.0  Australian Grand Prix
#
#    relative_perf  post  treated
# 0       0.022727     0        0
# 1       0.136364     0        0

# %%
df2 = pd.read_parquet("../code/src/data/processed/team_race_panel_forecast.parquet")
print(df2.dtypes)
# Out:
# year               int64
# round              int64
# team              object
# avg_points       float64
# avg_position     float64
# race              object
# relative_perf    float64
# post               int64
# treated            int64
# new_reg            int64
# dtype: object
